# %% [markdown]
# # Loading a semantic map using knowrob
#
# This notebook demonstrates how to load a semantic map into KnowRob
#
# ### Importing KnowRob Modules
#
# We will first initialize KnowRob

# %%
from enum import Enum
import json
from knowrob import *

# Temporary workaround: we need access to expandName
import dfl.dlquery as dl
    
InitKnowRob()

# %% [markdown]
# ## Setup Visualization

# %%
from sidecar import Sidecar
import os
from IPython.display import display, HTML

def display_desktop(anchor='right'):
    try:
        JUPYTERHUB_USER = os.environ['JUPYTERHUB_USER']
    except KeyError:
        JUPYTERHUB_USER = None
    url_prefix = f"/user/{JUPYTERHUB_USER}" if JUPYTERHUB_USER is not None else ''
    remote_desktop_url = f"{url_prefix}/desktop"
    sc = Sidecar(title='Desktop', anchor=anchor)
    with sc:
        # The inserted custom HTML and CSS snippets are to make the tab resizable
        display(HTML(f"""
            <style>
            body.p-mod-override-cursor div.iframe-widget {{
                position: relative;
                pointer-events: none;

            }}

            body.p-mod-override-cursor div.iframe-widget:before {{
                content: '';
                position: absolute;
                top: 0;
                left: 0;
                right: 0;
                bottom: 0;
                background: transparent;
            }}
            </style>
            <div class="iframe-widget" style="width: calc(100% + 10px);height:100%;">
                <iframe src="{remote_desktop_url}" width="100%" height="100%"></iframe>
            </div>
        """))
        
display_desktop()

# %% [markdown]
# Open Rviz

# %%
# %%bash --bg
# roscore &
# rviz -d knowrob.rviz

# %% [markdown]
# Example of object highlighting

# %%
from geometry_msgs.msg import Twist, Vector3
from visualization_msgs.msg import Marker, MarkerArray
import rospy
import random

rospy.init_node('highlight_object')
rate = rospy.Rate(1)  # 1 Hz
pub = rospy.Publisher('/marker_array', MarkerArray, queue_size=10)
num_object = 5

def create_marker_array(highlight=0):
    marker_array = MarkerArray()

    # Add some markers to the array
    for i in range(num_object):
        marker = Marker()
        marker.header.frame_id = "map"
        marker.header.stamp = rospy.Time.now()
        marker.ns = "example_markers"
        marker.id = i
        marker.type = Marker.SPHERE
        marker.action = Marker.ADD

        # Set marker position
        marker.pose.position.x = -2 + i * 1.0
        marker.pose.position.y = 0
        marker.pose.position.z = 0
        marker.pose.orientation.x = 0.0
        marker.pose.orientation.y = 0.0
        marker.pose.orientation.z = 0.0
        marker.pose.orientation.w = 1.0

         # Set marker scale
        marker.scale.x = 0.5
        marker.scale.y = 0.5
        marker.scale.z = 0.5
        
        # Set marker color
        marker.color.r = 0
        marker.color.g = 1
        marker.color.b = 0
        marker.color.a = 0.3
        
        # Add marker to the array
        marker_array.markers.append(marker)
    marker_array.markers[highlight].color.a = 1
    return marker_array

# highlight markers
for i in range(num_object):
    marker_array = create_marker_array(highlight=i%num_object)
    pub.publish(marker_array)
    rospy.loginfo("Highlighting SPHERE %dth", i)
    rate.sleep()

# %% [markdown]
# ### Setting Up Knowledge Base
#
# Now we set up the knowledge base. See the second data-sources field, to see the path to an expected ontology. Add this ontology before running this cell.

# %%
# Sample dictionary to be converted to JSON
sample_dict = {
	"logging": {
		"console-sink": {"level": "debug"},
		"file-sink": {"level": "debug"}
	},
	"semantic-web": {
		"prefixes": [
            {"alias": "dul", "uri": "http://www.ontologydesignpatterns.org/ont/dul/DUL.owl"},
			{"alias": "USD", "uri": "https://ease-crc.org/ont/USD.owl"},
            {"alias": "dfl", "uri": "http://www.ease-crc.org/ont/SOMA_DFL.owl"}
		]
	},
	"data-sources": [
		{"path": "owl/USD.owl", "format": "rdf-xml"},
        {"path": "owl/apartmentICRA.owl", "format": "rdf-xml"}
	],
	"data-backends": [
    {
      "type": "Redland",
      "name": "redland",
      "read-only": False
    }
	],  
    "reasoner": [
    {
      "type": "SOMADFLReasoner",
      "name": "DFLReasoner",
      "module": "reasoner/dfl_reasoner.py",
      "data-backend": "redland"
    }
    ]
}
# Convert the dictionary to a JSON string
json_str = json.dumps(sample_dict)
# Initialize the KnowledgeBase with the PropertyTree
kb = KnowledgeBase(json_str)

def runQuery(queryStr):
    phi = QueryParser.parse(queryStr)
    resultStream = kb.submitQuery(phi, QueryContext(QueryFlag.QUERY_FLAG_ALL_SOLUTIONS))
    resultQueue = resultStream.createQueue()
    retq = None
    result = resultQueue.pop_front()
    while not result.indicatesEndOfEvaluation():
        if retq is None:
            retq = []
        if isinstance(result, AnswerYes):
            aux = {}
            for substitution in result.substitution():
                variable, term = substitution[1], substitution[2]
                svar, sterm = None, None
                try:
                    svar, sterm = str(variable), str(term)
                except:
                    pass
                if (svar is not None) and (sterm is not None):
                    aux[svar] = str(sterm)
            retq.append(aux)
        elif isinstance(result, AnswerNo):
            retq = None
            break
        result = resultQueue.pop_front()
    return retq

# Some useful shortcuts in the ontology

class SOMADFL:
    storingTask = "dfl:store.v.wn.possession..place"
    servingFoodTask = 'dfl:serve.v.wn.consumption..concrete'
    eatingPatient = "dfl:eat.v.wn.consumption..food.Patient"
    graspingPatient = "dfl:hold.v.wn.contact..grasp.Theme"
    servingFoodLocation = "http://www.ease-crc.org/ont/SOMA_DFL.owl#serve.v.wn.consumption..concrete.Location"
    breakfastFoodClass = "dfl:breakfast_food.n.wn.food"
    solidFoodClass = "dfl:food.n.wn.food..solid"
# Out:
# [13:36:59.359] [info] Using backend `redland` with type `Redland`.
# [13:36:59.360] [info] [redland] using storage of type "memory" with name "knowrob" and options "contexts='yes'".
# [13:36:59.360] [info] Using queryable backend with id 'redland'.
# [13:36:59.361] [info] Loading ontology at '/home/jovyan/workspace/ros/src/knowrob/owl/rdf-schema.xml' with version "Mon Sep  2 14:09:14 2024" and origin "rdf-schema".
# [13:36:59.363] [info] Loading ontology at '/home/jovyan/workspace/ros/src/knowrob/owl/owl.rdf' with version "Mon Sep  2 14:09:14 2024" and origin "owl".
# [13:36:59.365] [info] Loading ontology at '/home/jovyan/.knowrob/owl/USD.owl' with version "Sat Sep 14 19:35:37 2024" and origin "USD".
# [13:36:59.374] [info] Loading ontology at '/home/jovyan/workspace/ros/src/knowrob/owl/external/DUL.owl' with version "17-01-2025" and origin "DUL".
# [13:36:59.393] [info] Loading ontology at '/home/jovyan/.knowrob/owl/apartmentICRA.owl' with version "Sat Sep 14 19:35:37 2024" and origin "apartmentICRA".
# [13:36:59.452] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.452] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.452] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.452] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.452] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.452] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.452] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.453] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.453] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.453] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.453] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.453] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.453] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.453] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.453] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.453] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.453] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.453] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.453] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.454] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.454] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.454] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.458] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.458] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.458] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.458] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.458] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.458] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.458] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.458] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.458] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.458] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.458] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.458] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.458] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.458] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.458] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.459] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.459] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.459] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.459] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.459] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.459] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.459] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.459] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.459] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.459] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.459] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.459] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.460] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.460] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.460] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.460] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.460] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.460] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.460] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.460] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.460] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.460] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.460] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.460] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.460] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.461] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.461] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.461] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.461] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.461] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.464] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.464] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.464] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.464] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.464] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.464] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.464] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.464] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.464] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.475] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.475] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.475] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.475] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.475] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.475] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.475] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.475] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.475] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.476] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.476] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.476] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.476] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.476] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.476] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.476] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.476] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.476] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.476] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.476] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.476] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.477] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.477] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.477] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.477] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.477] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.477] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.477] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.477] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.477] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.477] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.477] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.477] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.477] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.477] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.477] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.480] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.480] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.481] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.481] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.481] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.481] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.481] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.481] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.481] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.482] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.482] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.482] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.482] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.482] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.482] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.482] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.482] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.482] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.482] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.482] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.482] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.483] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.483] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.483] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.483] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.483] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.483] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.483] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.483] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.483] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.483] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.483] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.483] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.483] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.483] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.483] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.484] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.484] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.486] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.487] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.487] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.487] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.487] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.487] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.487] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.487] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.487] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.487] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.487] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.487] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.487] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.487] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.487] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.487] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.487] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.487] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.488] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.488] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.488] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.488] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.488] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.488] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.488] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.488] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.488] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.488] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.488] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.488] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.488] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.488] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.488] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.489] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.489] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.489] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.489] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.489] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.489] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.489] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.489] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.489] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.489] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.489] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.489] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.489] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.492] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.492] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.492] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.492] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.492] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.492] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.493] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.493] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.493] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.493] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.493] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.493] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.493] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.493] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.493] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.493] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.493] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.493] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.493] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.493] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.493] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.494] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.494] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.494] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.494] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.494] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.494] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.494] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.494] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.494] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.494] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.494] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.494] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.494] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.494] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.494] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.495] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.495] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.495] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.495] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.495] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.495] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.495] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.495] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.495] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.495] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.495] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.495] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.498] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.498] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.498] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.498] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.498] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.498] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.498] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.498] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.498] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.498] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.499] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.499] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.499] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.499] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.499] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.499] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.499] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.499] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.499] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.499] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.499] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.499] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.499] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.499] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.499] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.499] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.499] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.500] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.500] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.500] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.500] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.500] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.500] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.500] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.500] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.500] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.500] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.500] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.500] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.500] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.500] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.500] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.501] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.501] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.501] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.501] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.501] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.501] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.504] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.504] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.504] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.504] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.504] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.504] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.504] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.504] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.504] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.504] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.504] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.504] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.504] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.504] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.504] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.505] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.506] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.507] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.507] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.507] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.507] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.507] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.507] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.507] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.507] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.507] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.507] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.509] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.509] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.509] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.509] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.510] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.511] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#quatf treated as string.
# [13:36:59.512] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#point3f treated as string.
# [13:36:59.512] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#token_array treated as string.
# [13:36:59.512] [warning] Unknown XSD type IRI https://ease-crc.org/ont/USD.owl#matrix4d treated as string.
# [13:36:59.514] [info] Loading ontology at '/home/jovyan/workspace/ros/src/knowrob/owl/external/SOMA.owl' with version "17-01-2025" and origin "SOMA".
# [13:36:59.628] [info] Using reasoner `DFLReasoner` with type `SOMADFLReasoner`.
# [13:37:17.194] [info] Using goal-driven reasoner with id 'DFLReasoner'.

# %% [markdown]
# ### Submitting the Competency Questions
#
# Now we we will run the competency questions.
#
# #### CQ1: Which objects do I need for breakfast?
#
# This will return items that are considered breakfast food, and tools that may be needed to serve these. Some scenes may not contain breakfast food, so we will also inquire what food is there in general.

# %%
# CQ1: which objects do I need for breakfast? -- reinterpreted as, what objects are subclasses of breakfast food, 
# and what can I use to serve those

# Are there any objects that are instances of breakfast food?
bdgs = runQuery(f"dfl:isInstanceOf(?x, \'{SOMADFL.breakfastFoodClass}\')")
breakfastFoodItems = [x["?x"] for x in (bdgs or [])]

# Are there any objects that contain something that is a breakfast food?

#     First, what kinds of breakfast food are there?
bdgs = runQuery(f"dfl:isSubclassOf(?x, '{SOMADFL.breakfastFoodClass}')")
breakfastFoodClasses = [x["?x"] for x in (bdgs or [])]

#     Second, what containers for these things are around?
containerItems = set()
breakfastFoodClassesPresent = set()
for food in breakfastFoodClasses:
    bdgs = runQuery(f"dfl:hasPart(?x, '{food}')")
    containerItems = containerItems.union([x["?x"] for x in (bdgs or [])])
    if (bdgs is not None) and (0 < len(bdgs)):
        breakfastFoodClassesPresent.add(food)

# What sort of tools are used to serve the breakfast food we found 
#     (either as stand-alone items, or contained somewhere)?
toolItems = set()
for food in set().union(breakfastFoodItems).union(breakfastFoodClassesPresent):
    bdgs = runQuery(f"dfl:useMatch('{SOMADFL.servingFoodTask}', ?x, '{food}')")
    toolItems = toolItems.union([x["?x"] for x in (bdgs or [])])

# Report the results
edibles = containerItems.union(breakfastFoodItems)
print("These things look like breakfast food or contain some breakfast food: %s" % str(sorted(edibles)))
print(" ... and might need these items to serve them: %s" % str(sorted(list(toolItems))))

# Let's also try looking for food in general

bdgs = runQuery(f"dfl:hasDisposition(?x, '{SOMADFL.eatingPatient}')")
foodItems = [x["?x"] for x in (bdgs or [])]

# Are there any objects that contain something that is a breakfast food?

#     First, what kinds of breakfast food are there?
bdgs = runQuery(f"dfl:isSubclassOf(?x, '{SOMADFL.solidFoodClass}')")
foodClasses = [x["?x"] for x in (bdgs or [])]

#     Second, what containers for these things are around?
containerItems = set()
foodClassesPresent = set()
for food in foodClasses:
    bdgs = runQuery(f"dfl:hasPart(?x, '{food}')")
    containerItems = containerItems.union([x["?x"] for x in (bdgs or [])])
    if (bdgs is not None) and (0 < len(bdgs)):
        foodClassesPresent.add(food)

# What sort of tools are used to serve the breakfast food we found 
#     (either as stand-alone items, or contained somewhere)?
toolItems = set()
for food in set().union(foodItems).union(foodClassesPresent):
    bdgs = runQuery(f"dfl:useMatch('{SOMADFL.servingFoodTask}', ?x, '{food}')")
    toolItems = toolItems.union([x["?x"] for x in (bdgs or [])])

# Report the results
edibles = containerItems.union(foodItems)
print("If looking for food in general, these things look like they might fit: %s" % str(sorted(edibles)))
print(" ... and might need these items to serve them: %s" % str(sorted(list(toolItems))))

# %% [markdown]
# #### CQ2 What are the storage locations for our food items?

# %%
# CQ2: Where can we find the food?

if 0 < len(edibles):
    locations = {}
    for food in edibles:
        bdgs = runQuery(f"dfl:useMatch('{SOMADFL.storingTask}', ?x, '{food}')")
        locations[food] = [x["?x"] for x in (bdgs or [])]
    
    # Report the results
    print("Places where to look for food:")
    for food in sorted(list(locations.keys())):
        print(f"{food}: {sorted(locations[food])}")
else:
    print("Did not find anything edible in this scene at CQ1 so will skip CQ2 ...")

# %% [markdown]
# #### CQ3 Where do we expect an item to be?

# %%
# CQ3: Where do we expect an item to be? -- note, there is no ranking of locations by likelihood,
# and there may be many plausible locations!

# For example, lets pick a tool from CQ1
if 0 < len(toolItems):
    locations = {}
    for tool in toolItems:
        bdgs = runQuery(f"dfl:useMatch('{SOMADFL.storingTask}', ?x, '{tool}')")
        locations[tool] = [x["?x"] for x in (bdgs or [])]

    # Report results
    print("Places where to look for tools:")
    for tool in sorted(list(locations.keys())):
        print(f"{tool}: {sorted(locations[tool])}")
else:
    print("Did not find any tools at CQ1 so will skip CQ3 ...")

# %% [markdown]
# #### CQ4 What can I grasp on an object?

# %%
# CQ4: What can I grasp on an object to open it?

# For example, lets pick a tool from CQ1
if 0 < len(toolItems):
    item = list(toolItems)[0]
    
    # What parts does the object have?
    bdgs = runQuery(f"dul:hasPart('{dl.expandName(item)}', ?x)")
    parts = [x["?x"] for x in (bdgs or [])]
    parts = set(parts).union([item])
    
    # Which of them are graspable?
    graspables = set()
    for part in parts:
        bdgs = runQuery(f"dfl:hasDisposition('{part}', '{SOMADFL.graspingPatient}')")
        if bdgs is not None:
            graspables.add(part)
            
    # IF complex queries work (and assuming an object has itself as part, or else a disjunction is needed):
    # bdgs = runQuery(f"dul:hasPart('{item}', ?x), dfl:hasDisposition(?x, 'dfl:hold.v.wn.contact..grasp')")
    # graspables = [x["?x"] for x in bdgs]
    # Report results
    print("Can try to grasp %s by grasping one of %s" % (item, str(sorted(list(graspables)))))
    
else:
    print("Did not find any tools at CQ1 so will skip CQ4 ...")

# %% [markdown]
# #### CQ5 Where should I put the utensils for breakfast?

# %%
# CQ5: Where to place the utensils for breakfast?

bdgs = runQuery(f"dfl:hasDisposition(?x, '{SOMADFL.servingFoodLocation}')")
locations = [x["?x"] for x in (bdgs or [])]

# Report results
print("You could set up the meal at one of these locations: %s" % str(locations))
